# %% [markdown]
# # Flipkart GRID 4.0

# %% [markdown]
# * The u-net is convolutional network architecture for fast and precise segmentation of images. Up to now it has outperformed the prior best method (a sliding-window convolutional network) on the ISBI challenge for segmentation of neuronal structures in electron microscopic stacks.

# %%
import tqdm
import numpy as np
from matplotlib import pyplot as plt

import cv2 as cv

import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.losses import *
from tensorflow.keras.optimizers import *
from tensorflow.keras import backend as K

# %%
### PLOT ONE SAMPLE OF IMAGE IN THE DATA ###

original = cv.imread('C:/Users/rakes/'+'multiclass_segmentation/original77.jpg')
original = cv.resize(original,(224,224))
dress = cv.imread('C:/Users/rakes/'+'multiclass_segmentation/dress77.jpg')
dress = cv.resize(dress,(224,224))
body = cv.imread('C:/Users/rakes/'+'multiclass_segmentation/body77.jpg')
body = cv.resize(body,(224,224))

plt.figure(figsize=(16,8))
plt.subplot(1,3,1)
plt.title('Original')
plt.imshow(cv.cvtColor(original, cv.COLOR_BGRA2RGB))
plt.subplot(1,3,2)
plt.title('Person')
plt.imshow(cv.cvtColor(body, cv.COLOR_BGRA2RGB))
plt.subplot(1,3,3)
plt.title('Dress')
plt.imshow(cv.cvtColor(dress, cv.COLOR_BGRA2RGB))

# %%
dress = cv.imread('C:/Users/rakes/'+'multiclass_segmentation/dress77.jpg',0)
body = cv.imread('C:/Users/rakes/'+'multiclass_segmentation/body77.jpg',0)

### ENCODE DRESS ###
dress[dress == 255] = 0
dress[dress > 0] = 255
dress = cv.resize(dress,(224,224))

### ENCODE BODY ###
body[body == 255] = 0
body[body > 0] = 255
body = cv.resize(body,(224,224))

### ENCODE SKIN ###
skin = body - dress


plt.figure(figsize=(16,8))
plt.subplot(1,3,1)
plt.title('Person/Background')
bg = (255 - body)/255
plt.imshow(bg)
plt.subplot(1,3,2)
plt.title('Skin')
skin = (255 - skin)/255
plt.imshow(skin)
plt.subplot(1,3,3)
plt.title('Dress')
dress = (255 - dress)/255
plt.imshow(dress)

# %%
root_path='C:/Users/rakes/'

# %%
### COMBINE BACKGROUND, SKIN, DRESS ###

gt = np.zeros((224,224,3))
gt[:,:,0] = (1-skin)
gt[:,:,1] = (1-dress)
gt[:,:,2] = bg

plt.figure(figsize=(6,6))
plt.imshow(gt)

# %%
root_path+'dress_new/'+str(1)+'.jpg'
# Out:
# 'C:/Users/rakes/dress_new/1.jpg'

# %%
### ENCODE BACKGROUND, SKIN, DRESS FOR ALL TRAIN IMAGES ###

images_original = []
images_gt = []

mean = np.zeros((224,224,3))
n_img = 5

for i in tqdm.tqdm(range(1,n_img+1)):
    
    original = cv.imread(root_path+'original_new/'+str(i)+'.jpg')
    original = cv.resize(original,(224,224))
    images_original.append(original)
    mean[:,:,0]=mean[:,:,0]+original[:,:,0]
    mean[:,:,1]=mean[:,:,1]+original[:,:,1]
    mean[:,:,2]=mean[:,:,2]+original[:,:,2]
    
    body = cv.imread(root_path+'body_new/'+str(i)+'.png',0)
    dress = cv.imread(root_path+'dress_new/'+str(i)+'.png',0)
    
    dress[dress == 255] = 0
    dress[dress > 0] = 255
    dress = cv.resize(dress,(224,224))

    body[body == 255] = 0
    body[body > 0] = 255
    body = cv.resize(body,(224,224))

    skin = body - dress
    bg = (255 - body)/255
    skin = (255 - skin)/255
    dress = (255 - dress)/255
    
    gt = np.zeros((224,224,3))
    gt[:,:,0] = (1-skin)
    gt[:,:,1] = (1-dress)
    gt[:,:,2] = bg
   
    images_gt.append(gt)

mean = mean / n_img
mean = mean.reshape((-1,224,224,3))

images_original = np.asarray(images_original)
images_gt = np.asarray(images_gt)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:06<00:00,  1.30s/it]

# %%
def get_unet(mean_pixels, do_rate=0):
  
    inputs = Input((None, None, 3))
    preproc = Lambda(lambda x: (x - tf.constant(mean_pixels, dtype=tf.float32)))(inputs) 

    conv1 = Dropout(do_rate)(Conv2D(32, (3, 3), padding='same', activation='relu')(preproc))
    conv1 = Dropout(do_rate)(Conv2D(32, (3, 3), padding='same', activation='relu')(conv1))
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Dropout(do_rate)(Conv2D(64, (3, 3), padding='same', activation='relu')(pool1))
    conv2 = Dropout(do_rate)(Conv2D(64, (3, 3), padding='same', activation='relu')(conv2))
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Dropout(do_rate)(Conv2D(128, (3, 3), padding='same', activation='relu')(pool2))
    conv3 = Dropout(do_rate)(Conv2D(128, (3, 3), padding='same', activation='relu')(conv3))
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Dropout(do_rate)(Conv2D(256, (3, 3), padding='same', activation='relu')(pool3))
    conv4 = Dropout(do_rate)(Conv2D(256, (3, 3), padding='same', activation='relu')(conv4))
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Dropout(do_rate)(Conv2D(512, (3, 3), padding='same', activation='relu')(pool4))
    conv5 = Dropout(do_rate)(Conv2D(512, (3, 3), padding='same', activation='relu')(conv5))

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Dropout(do_rate)(Conv2D(256, (3, 3), padding='same', activation='relu')(up6))
    conv6 = Dropout(do_rate)(Conv2D(256, (3, 3), padding='same', activation='relu')(conv6))

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Dropout(do_rate)(Conv2D(128, (3, 3), padding='same', activation='relu')(up7))
    conv7 = Dropout(do_rate)(Conv2D(128, (3, 3), padding='same', activation='relu')(conv7))

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Dropout(do_rate)(Conv2D(64, (3, 3), padding='same', activation='relu')(up8))
    conv8 = Dropout(do_rate)(Conv2D(64, (3, 3), padding='same', activation='relu')(conv8))

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Dropout(do_rate)(Conv2D(32, (3, 3), padding='same', activation='relu')(up9))
    conv9 = Dropout(do_rate)(Conv2D(32, (3, 3), padding='same', activation='relu')(conv9))

    conv10 = Conv2D(3, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=inputs, outputs=conv10)

    model.compile(optimizer=Adam(lr=1e-3), loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
model = get_unet(mean)
model.fit(images_original, images_gt, epochs=120)
# Out:
# C:\Users\rakes\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/120
# 1/1 [==============================] - 39s 39s/step - loss: 2.3870 - accuracy: 0.3290
# Epoch 2/120
# 1/1 [==============================] - 14s 14s/step - loss: 0.8590 - accuracy: 0.4931
# Epoch 3/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.8274 - accuracy: 0.5510
# Epoch 4/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.7146 - accuracy: 0.5374
# Epoch 5/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.6156 - accuracy: 0.5698
# Epoch 6/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.5919 - accuracy: 0.5970
# Epoch 7/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.5792 - accuracy: 0.6146
# Epoch 8/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.5462 - accuracy: 0.6175
# Epoch 9/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.5352 - accuracy: 0.6219
# Epoch 10/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.5299 - accuracy: 0.6291
# Epoch 11/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.5131 - accuracy: 0.6372
# Epoch 12/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4979 - accuracy: 0.6446
# Epoch 13/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4895 - accuracy: 0.6507
# Epoch 14/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4838 - accuracy: 0.6537
# Epoch 15/120
# 1/1 [==============================] - 12s 12s/step - loss: 0.4774 - accuracy: 0.6553
# Epoch 16/120
# 1/1 [==============================] - 12s 12s/step - loss: 0.4717 - accuracy: 0.6568
# Epoch 17/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4671 - accuracy: 0.6581
# Epoch 18/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4617 - accuracy: 0.6612
# Epoch 19/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4565 - accuracy: 0.6661
# Epoch 20/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4511 - accuracy: 0.6731
# Epoch 21/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4459 - accuracy: 0.6790
# Epoch 22/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4419 - accuracy: 0.6843
# Epoch 23/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4403 - accuracy: 0.6878
# Epoch 24/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4326 - accuracy: 0.6938
# Epoch 25/120
# 1/1 [==============================] - 12s 12s/step - loss: 0.4319 - accuracy: 0.6943
# Epoch 26/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4231 - accuracy: 0.7019
# Epoch 27/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4227 - accuracy: 0.7039
# Epoch 28/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4115 - accuracy: 0.7107
# Epoch 29/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4165 - accuracy: 0.7059
# Epoch 30/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4135 - accuracy: 0.7168
# Epoch 31/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4048 - accuracy: 0.7233
# Epoch 32/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4012 - accuracy: 0.7158
# Epoch 33/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3859 - accuracy: 0.7363
# Epoch 34/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3815 - accuracy: 0.7446
# Epoch 35/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4058 - accuracy: 0.7135
# Epoch 36/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4998 - accuracy: 0.6738
# Epoch 37/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4392 - accuracy: 0.7132
# Epoch 38/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4042 - accuracy: 0.7238
# Epoch 39/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4527 - accuracy: 0.6697
# Epoch 40/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4155 - accuracy: 0.6946
# Epoch 41/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4117 - accuracy: 0.6981
# Epoch 42/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4181 - accuracy: 0.6999
# Epoch 43/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4207 - accuracy: 0.7062
# Epoch 44/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4166 - accuracy: 0.7110
# Epoch 45/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4077 - accuracy: 0.7145
# Epoch 46/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3994 - accuracy: 0.7179
# Epoch 47/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3974 - accuracy: 0.7200
# Epoch 48/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4019 - accuracy: 0.7186
# Epoch 49/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4024 - accuracy: 0.7175
# Epoch 50/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3925 - accuracy: 0.7253
# Epoch 51/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3846 - accuracy: 0.7274
# Epoch 52/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3812 - accuracy: 0.7322
# Epoch 53/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3775 - accuracy: 0.7306
# Epoch 54/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3635 - accuracy: 0.7456
# Epoch 55/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3692 - accuracy: 0.7447
# Epoch 56/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4405 - accuracy: 0.6698
# Epoch 57/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4082 - accuracy: 0.7214
# Epoch 58/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4329 - accuracy: 0.7049
# Epoch 59/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4149 - accuracy: 0.7197
# Epoch 60/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4020 - accuracy: 0.7233
# Epoch 61/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3989 - accuracy: 0.7230
# Epoch 62/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4088 - accuracy: 0.7198
# Epoch 63/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4166 - accuracy: 0.7145
# Epoch 64/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.4030 - accuracy: 0.7206
# Epoch 65/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3844 - accuracy: 0.7309
# Epoch 66/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3744 - accuracy: 0.7393
# Epoch 67/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3737 - accuracy: 0.7460
# Epoch 68/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3779 - accuracy: 0.7432
# Epoch 69/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3731 - accuracy: 0.7454
# Epoch 70/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3512 - accuracy: 0.7627
# Epoch 71/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3397 - accuracy: 0.7715
# Epoch 72/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3267 - accuracy: 0.7784
# Epoch 73/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3299 - accuracy: 0.7656
# Epoch 74/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3300 - accuracy: 0.8049
# Epoch 75/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3556 - accuracy: 0.7286
# Epoch 76/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3577 - accuracy: 0.7203
# Epoch 77/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3760 - accuracy: 0.7445
# Epoch 78/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3460 - accuracy: 0.7474
# Epoch 79/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3467 - accuracy: 0.7654
# Epoch 80/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3433 - accuracy: 0.7803
# Epoch 81/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3263 - accuracy: 0.7948
# Epoch 82/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3169 - accuracy: 0.7934
# Epoch 83/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.3016 - accuracy: 0.8084
# Epoch 84/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.2880 - accuracy: 0.8037
# Epoch 85/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.2844 - accuracy: 0.8069
# Epoch 86/120
# 1/1 [==============================] - 12s 12s/step - loss: 0.2761 - accuracy: 0.8068
# Epoch 87/120
# 1/1 [==============================] - 12s 12s/step - loss: 0.2576 - accuracy: 0.8218
# Epoch 88/120
# 1/1 [==============================] - 41s 41s/step - loss: 0.2761 - accuracy: 0.8458
# Epoch 89/120
# 1/1 [==============================] - 20s 20s/step - loss: 0.3807 - accuracy: 0.7118
# Epoch 90/120
# 1/1 [==============================] - 13s 13s/step - loss: 0.2687 - accuracy: 0.8145
# Epoch 91/120
# 1/1 [==============================] - 14s 14s/step - loss: 0.2919 - accuracy: 0.8135
# Epoch 92/120
# 1/1 [==============================] - 17s 17s/step - loss: 0.3280 - accuracy: 0.8042
# Epoch 93/120
# 1/1 [==============================] - 18s 18s/step - loss: 0.3002 - accuracy: 0.8125
# Epoch 94/120
# 1/1 [==============================] - 12s 12s/step - loss: 0.2968 - accuracy: 0.8144
# Epoch 95/120
# 1/1 [==============================] - 12s 12s/step - loss: 0.2889 - accuracy: 0.8171
# Epoch 96/120
# 1/1 [==============================] - 13s 13s/step - loss: 0.2893 - accuracy: 0.8152
# Epoch 97/120
# 1/1 [==============================] - 15s 15s/step - loss: 0.2817 - accuracy: 0.8189
# Epoch 98/120
# 1/1 [==============================] - 12s 12s/step - loss: 0.2460 - accuracy: 0.8397
# Epoch 99/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.2556 - accuracy: 0.8519
# Epoch 100/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.2519 - accuracy: 0.8274
# Epoch 101/120
# 1/1 [==============================] - 12s 12s/step - loss: 0.2564 - accuracy: 0.8248
# Epoch 102/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.2666 - accuracy: 0.8577
# Epoch 103/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.2293 - accuracy: 0.8433
# Epoch 104/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.2237 - accuracy: 0.8489
# Epoch 105/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.2356 - accuracy: 0.8492
# Epoch 106/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.2146 - accuracy: 0.8639
# Epoch 107/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.2082 - accuracy: 0.8694
# Epoch 108/120
# 1/1 [==============================] - 12s 12s/step - loss: 0.2334 - accuracy: 0.8658
# Epoch 109/120
# 1/1 [==============================] - 14s 14s/step - loss: 0.2944 - accuracy: 0.7941
# Epoch 110/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.2935 - accuracy: 0.7919
# Epoch 111/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.2274 - accuracy: 0.8420
# Epoch 112/120
# 1/1 [==============================] - 16s 16s/step - loss: 0.3164 - accuracy: 0.8074
# Epoch 113/120
# 1/1 [==============================] - 12s 12s/step - loss: 0.2516 - accuracy: 0.8298
# Epoch 114/120
# 1/1 [==============================] - 12s 12s/step - loss: 0.2871 - accuracy: 0.8017
# Epoch 115/120
# 1/1 [==============================] - 14s 14s/step - loss: 0.2902 - accuracy: 0.7987
# Epoch 116/120
# 1/1 [==============================] - 13s 13s/step - loss: 0.2806 - accuracy: 0.8081
# Epoch 117/120
# 1/1 [==============================] - 11s 11s/step - loss: 0.2745 - accuracy: 0.8173
# Epoch 118/120
# 1/1 [==============================] - 12s 12s/step - loss: 0.2731 - accuracy: 0.8201
# Epoch 119/120
# 1/1 [==============================] - 13s 13s/step - loss: 0.2711 - accuracy: 0.8231
# Epoch 120/120
# 1/1 [==============================] - 13s 13s/step - loss: 0.2594 - accuracy: 0.8312

# %%
### SAVE TRAINED MODEL ###

model.save(root_path+'trained_models/fashion_unet.h5')
